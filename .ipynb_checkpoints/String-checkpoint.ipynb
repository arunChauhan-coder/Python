# %%
l1 = ["Sam", "Karan", "Mohit"]

# %%
" ".join(l1)
# Out:
# 'Sam Karan Mohit'

# %%
"".join(l1)
# Out:
# 'SamKaranMohit'

# %%
l1
# Out:
# ['Sam', 'Karan', 'Mohit']

# %%
l2 = [100.0,200.43,77]

# %%
l3 = tuple(map(int,l2))

# %%
l3
# Out:
# (100, 200, 77)

# %%
def sq(x1):
    return x1*x1

l4 = tuple(map(sq,l3))
l4
# Out:
# (10000, 40000, 5929)

# %%
l5 = any(x>80 for x in l3)
l5
# Out:
# True

# %%
l5 = [i+1 for i in l3 if i>80 ]

# %%
l5
# Out:
# [101, 201]

# %%
l5 = list(map(lambda x: x if x>80 else None,l3))

# %%
l5  # none is the issue
# Out:
# [100, 200, None]

# %%
l5 = list(filter(lambda x:x>80,l3))

# %%
l5
# Out:
# [100, 200]

# %%
l5 = [i for i in l3 if i>80]
l5
# Out:
# [100, 200]

# %% [markdown]
# ## Diff bw map and filter

# %% [markdown]
# ![Untitled.png](attachment:Untitled.png)

# %% [markdown]
# ## String

# %%
# Python program to check whether the string is Symmetrical or Palindrome

# %%
def check(string):
    string = string.replace(" ","")
    print(string)
    if ( string == string[::-1]):
        return "String is Palindrome"
        
    elif len(string)% 2 == 0 and string[:(len(string)//2)]== string[len(string)//2:]:
        return " String is Symmetric " 
    
    else:
        return "Niether palendrome nor symmetric"

# %%
check("khokho")
# Out:
# khokho
# ' String is Symmetric '

# %%
check("kho kho ")
# Out:
# khokho
# ' String is Symmetric '

# %%
check("madam")
# Out:
# 'String is Palindrome'

# %%
check("111189")
# Out:
# 'Niether palendrome nor symmetric'

# %%
# Reverse Words in a Given String in Python
s = input("Enter String: ")
# Out:
# Enter String: you good

# %%
t1 = s.split()
t1
# Out:
# ['you', 'good']

# %%
t1 = t1[::-1]
s= " ".join(t1)
s
# Out:
# 'good you'

# %%
# 2nd approch
s = input("Enter String: ")
# Out:
# Enter String: Arun is good

# %%
t1 = s.split()[::-1]
s= " ".join(t1)
type(t1)
# Out:
# list

# %%
s
# Out:
# 'good is Arun'

# %%
# Avoid Spaces in string length

# %%
st = "kara n 12 si ngh"

# %%
st= st.replace(" ","")
st
# Out:
# 'karan12singh'

# %%
len(st)
# Out:
# 12

# %%
#  Python program to print even length words in a string

# %%
st = "shym is a excellent boy"

# %%
l1= st.split()

# %%
l2 = []
for i in l1:
    if len(i)%2 == 0:
        l2.append(i)

# %%
st = " ".join(l2)
st
# Out:
# 'shym is'

# %%
# Python – Uppercase Half String

# %%
st = "apples"

# %%
st[:int(len(st)/2)] + st[int(len(st)/2)::1 ].upper()
# Out:
# 'appLES'

# %%
# Convert numeric words to numbers

# %%
S = "zero four zero one"

# %%
d = {
    "zero": '1',
    "one" : '2',
    "two" : '3',
    "four": '4',
    "five": '5',
    "six" : '6',
    "seven":'7',
    "eight":'8',
    "nine": '9'
}

# %%
n = "".join(d[ele] for ele in (S.split()))

# %%
n
# Out:
# '1412'

# %%
from itertools import groupby

test_str = "geekksforgggeeks"

for i,j in groupby(test_str):
    print(i,len(list(j)))
# Out:
# g 1
# e 2
# k 2
# s 1
# f 1
# o 1
# r 1
# g 3
# e 2
# k 1
# s 1

# %%
# String slicing in Python to check if a string can become empty by recursive deletion

# %%
str1 = "GEEGEEKSKS"
sub_str = "GEEK"

# %%
def rec_del(str1,sub_str):
    while len(str1)!=0:
        if sub_str in str1:
            #str1 = str1[str1.index(sub_str):str1.index(sub_str)+len(sub_str)]
            str1 = str1.replace(sub_str,"")
        else :
            print("String is not empty but it doesnt contain sub string")
            break
    else:
        print("string can become empty by recursive deletion")

# %%
rec_del("GEEGEEKSKS","GEEK")
# Out:
# String is not empty but it doesnt contain sub string

# %%
rec_del("GEEGEEKSKS","GEEKS")
# Out:
# string can become empty by recursive deletion
